# %% [markdown]
# (C) Crown Copyright, Met Office. All rights reserved.

# %% [markdown]
# ## vars_retrieved_20200626.ipynb
#
# This notebook calculates the number of variables that have been requested for retrieval from tape to disk at JASMIN by the PRIMAVERA project using data from the DMT. The number is the number of times that this variable has been requested. A value of 1 means that this variable has been requested once from a single model for a single experiment. 7 could mean that this variable had been requested from all models for a single experiment, or that the same variable from one model and experiment has been requested by seven different people. The name is in the form "var-name_table-name" and the table name includes the frequency of that variable. The variable's standard name is included in the third column.

# %%
import datetime
print(f'Last run {datetime.datetime.utcnow()}')
# Out:
# Last run 2020-06-29 09:17:25.696678

# %%
from collections import OrderedDict

import django
django.setup()
from pdata_app.models import DataRequest, RetrievalRequest, VariableRequest

# %%
var_reqs = {}

# Ignore retrievals by Jon as these were for publication rather than analysis
for rr in RetrievalRequest.objects.exclude(requester__username='jseddon').order_by('id'):
    for dr in rr.data_request.all():
        if dr.variable_request not in var_reqs:
            var_reqs[dr.variable_request] = 1
        else:
            var_reqs[dr.variable_request] += 1

# %%
var_reqs_ordered = OrderedDict(sorted(var_reqs.items(), key=lambda x: (x[0].frequency, x[0].table_name, x[0].cmor_name)))

# %% [markdown]
# Look at the variables requested for retrieval.
#
# The number is the number of times that this variable has been requested. A value of 1 means that this variable has been requested once from a single model for a single experiment. 7 could mean that this variable had been requested from all models for a single experiment, or that the same variable from one model and experiment has been requested by seven different people.

# %%
for vr in var_reqs_ordered:
    print('{:<20} {:3}   {}'.format(vr.cmor_name + '_' + vr.table_name, var_reqs[vr], vr.standard_name))
# Out:
# pr_E1hr               28   precipitation_flux
# clt_Prim1hr            4   cloud_area_fraction_in_atmosphere_layer
# rsds_Prim1hr           8   surface_downwelling_shortwave_flux_in_air
# rsdsdiff_Prim1hr       2   surface_diffuse_downwelling_shortwave_flux_in_air
# tas_Prim1hr           18   air_temperature
# ua50m_Prim1hr          4   eastward_wind
# uas_Prim1hr           29   eastward_wind
# va50m_Prim1hr          4   northward_wind
# vas_Prim1hr           24   northward_wind
# clt_3hr                2   cloud_area_fraction
# hfls_3hr              43   surface_upward_latent_heat_flux
# hfss_3hr              34   surface_upward_sensible_heat_flux
# huss_3hr              48   specific_humidity
# mrro_3hr              22   runoff_flux
# mrsos_3hr              8   moisture_content_of_soil_layer
# pr_3hr               146   precipitation_flux
# prc_3hr               11   convective_precipitation_flux
# prsn_3hr               9   snowfall_flux
# ps_3hr                18   surface_air_pressure
# rlds_3hr              45   surface_downwelling_longwave_flux_in_air
# rldscs_3hr            30   surface_downwelling_longwave_flux_in_air_assuming_clear_sky
# rlus_3hr              38   surface_upwelling_longwave_flux_in_air
# rsds_3hr              15   surface_downwelling_shortwave_flux_in_air
# rsdscs_3hr             3   surface_downwelling_shortwave_flux_in_air_assuming_clear_sky
# rsus_3hr              33   surface_upwelling_shortwave_flux_in_air
# tas_3hr               13   air_temperature
# tslsi_3hr              1   surface_temperature
# tso_3hr                1   sea_surface_temperature
# uas_3hr               72   eastward_wind
# vas_3hr               70   northward_wind
# prw_E3hr              47   atmosphere_water_vapor_content
# psl_E3hr              27   air_pressure_at_sea_level
# rsdt_E3hr              2   toa_incoming_shortwave_flux
# hus7h_E3hrPt          24   specific_humidity
# psl_E3hrPt             8   air_pressure_at_sea_level
# ta7h_E3hrPt           29   air_temperature
# ua7h_E3hrPt           33   eastward_wind
# ua850_E3hrPt           1   eastward_wind
# va7h_E3hrPt           30   northward_wind
# va850_E3hrPt           1   northward_wind
# wap7h_E3hrPt           4   lagrangian_tendency_of_air_pressure
# sfcWind_Prim3hr       17   wind_speed
# sfcWindmax_Prim3hr     1   wind_speed
# ua100m_Prim3hrPt       3   eastward_wind
# ua50m_Prim3hrPt        1   eastward_wind
# va100m_Prim3hrPt       3   northward_wind
# va50m_Prim3hrPt        1   northward_wind
# zg7h_Prim3hrPt       111   geopotential_height
# tos_3hr                1   sea_surface_temperature
# psl_CF3hr              1   air_pressure_at_sea_level
# psl_6hrPlev           14   air_pressure_at_sea_level
# hus7h_6hrPlevPt       37   specific_humidity
# huss_6hrPlevPt        21   specific_humidity
# psl_6hrPlevPt        100   air_pressure_at_sea_level
# sfcWind_6hrPlevPt     38   wind_speed
# ta_6hrPlevPt           6   air_temperature
# ta7h_6hrPlevPt         6   air_temperature
# tas_6hrPlevPt          8   air_temperature
# ts_6hrPlevPt           1   surface_temperature
# ua_6hrPlevPt          67   eastward_wind
# ua7h_6hrPlevPt        52   eastward_wind
# uas_6hrPlevPt        110   eastward_wind
# va_6hrPlevPt          65   northward_wind
# va7h_6hrPlevPt        48   northward_wind
# vas_6hrPlevPt        112   northward_wind
# vortmean_6hrPlevPt     1   atmosphere_relative_vorticity
# zg27_6hrPlevPt        27   geopotential_height
# zg7h_6hrPlevPt       107   geopotential_height
# clt_Prim6hr            2   cloud_area_fraction
# hfls_Prim6hr           2   surface_upward_latent_heat_flux
# hus4_Prim6hr           2   specific_humidity
# pr_Prim6hr            96   precipitation_flux
# prc_Prim6hr           52   convective_precipitation_flux
# ps_Prim6hr            15   surface_air_pressure
# rsds_Prim6hr           1   surface_downwelling_shortwave_flux_in_air
# sfcWindmax_Prim6hr     1   wind_speed_of_gust
# ua4_Prim6hr            2   eastward_wind
# va4_Prim6hr            3   northward_wind
# wsgmax_Prim6hr         7   wind_speed_of_gust
# clt_Prim6hrPt          2   cloud_area_fraction
# ps_Prim6hrPt           4   surface_air_pressure
# ua1000_Prim6hrPt       1   eastward_wind
# clivi_CFday            6   atmosphere_cloud_ice_content
# clw_CFday              3   mass_fraction_of_cloud_liquid_water_in_air
# clwvi_CFday            8   atmosphere_cloud_condensed_water_content
# phalf_CFday            3   air_pressure
# ps_CFday              10   surface_air_pressure
# rlutcs_CFday           2   toa_outgoing_longwave_flux_assuming_clear_sky
# rsdt_CFday             5   toa_incoming_shortwave_flux
# rsut_CFday             5   toa_outgoing_shortwave_flux
# rsutcs_CFday           2   toa_outgoing_shortwave_flux_assuming_clear_sky
# ua_CFday               4   eastward_wind
# va_CFday               4   northward_wind
# tauu_Eday              4   surface_downward_eastward_stress
# ua_Eday                2   eastward_wind
# va_Eday                1   northward_wind
# zg_EdayZ               8   geopotential_height
# tos_Oday              22   sea_surface_temperature
# uo_PrimOday            1   sea_water_x_velocity
# vo_PrimOday            2   sea_water_y_velocity
# zos_PrimOday           6   sea_surface_height_above_geoid
# evspsbl_Primday        9   water_evaporation_flux
# hus10_Primday          1   specific_humidity
# ta23_Primday           8   air_temperature
# ts_Primday            46   surface_temperature
# ua10_Primday           1   eastward_wind
# ua23_Primday           9   eastward_wind
# va10_Primday           1   northward_wind
# va23_Primday           8   northward_wind
# zg10_Primday          14   geopotential_height
# zg23_Primday         121   geopotential_height
# ua_PrimdayPt           2   eastward_wind
# siconc_SIday           5   sea_ice_area_fraction
# siu_SIday             17   sea_ice_x_velocity
# siv_SIday             18   sea_ice_y_velocity
# clt_day               18   cloud_area_fraction
# hfls_day              31   surface_upward_latent_heat_flux
# hfss_day              19   surface_upward_sensible_heat_flux
# hus_day               61   specific_humidity
# huss_day              25   specific_humidity
# mrro_day              26   runoff_flux
# mrsos_day             18   moisture_content_of_soil_layer
# pr_day               367   precipitation_flux
# psl_day               72   air_pressure_at_sea_level
# rlds_day              15   surface_downwelling_longwave_flux_in_air
# rlut_day              24   toa_outgoing_longwave_flux
# sfcWind_day           31   wind_speed
# sfcWindmax_day        62   wind_speed
# snw_day                4   surface_snow_amount
# ta_day                85   air_temperature
# tas_day               74   air_temperature
# tasmax_day           152   air_temperature
# tasmin_day            64   air_temperature
# ua_day               194   eastward_wind
# uas_day               81   eastward_wind
# va_day               161   northward_wind
# vas_day               84   northward_wind
# wap_day               18   lagrangian_tendency_of_air_pressure
# zg_day               544   geopotential_height
# sftlf_fx               1   land_area_fraction
# cl_Amon               20   cloud_area_fraction_in_atmosphere_layer
# cli_Amon               4   mass_fraction_of_cloud_ice_in_air
# clt_Amon             314   cloud_area_fraction
# clw_Amon               4   mass_fraction_of_cloud_liquid_water_in_air
# evspsbl_Amon         329   water_evaporation_flux
# hfls_Amon            236   surface_upward_latent_heat_flux
# hfss_Amon            234   surface_upward_sensible_heat_flux
# hur_Amon              34   relative_humidity
# hurs_Amon              3   relative_humidity
# hus_Amon             333   specific_humidity
# huss_Amon            323   specific_humidity
# pfull_Amon             6   air_pressure
# phalf_Amon             5   air_pressure
# pr_Amon              1261   precipitation_flux
# prc_Amon              68   convective_precipitation_flux
# prsn_Amon             32   snowfall_flux
# prw_Amon              87   atmosphere_water_vapor_content
# ps_Amon              322   surface_air_pressure
# psl_Amon             828   air_pressure_at_sea_level
# rlds_Amon            202   surface_downwelling_longwave_flux_in_air
# rldscs_Amon           47   surface_downwelling_longwave_flux_in_air_assuming_clear_sky
# rlus_Amon            131   surface_upwelling_longwave_flux_in_air
# rlut_Amon             83   toa_outgoing_longwave_flux
# rlutcs_Amon           42   toa_outgoing_longwave_flux_assuming_clear_sky
# rsds_Amon            178   surface_downwelling_shortwave_flux_in_air
# rsdscs_Amon           45   surface_downwelling_shortwave_flux_in_air_assuming_clear_sky
# rsdt_Amon             82   toa_incoming_shortwave_flux
# rsus_Amon            172   surface_upwelling_shortwave_flux_in_air
# rsuscs_Amon           33   surface_upwelling_shortwave_flux_in_air_assuming_clear_sky
# rsut_Amon             88   toa_outgoing_shortwave_flux
# rsutcs_Amon           43   toa_outgoing_shortwave_flux_assuming_clear_sky
# sfcWind_Amon           3   wind_speed
# ta_Amon              354   air_temperature
# tas_Amon             692   air_temperature
# tasmax_Amon           25   air_temperature
# tasmin_Amon           23   air_temperature
# tauu_Amon             26   surface_downward_eastward_stress
# tauv_Amon             26   surface_downward_northward_stress
# ts_Amon              834   surface_temperature
# ua_Amon              513   eastward_wind
# uas_Amon              29   eastward_wind
# va_Amon              417   northward_wind
# vas_Amon              32   northward_wind
# wap_Amon             144   lagrangian_tendency_of_air_pressure
# zg_Amon              361   geopotential_height
# hur_CFmon              1   relative_humidity
# hus_CFmon              1   specific_humidity
# rld_CFmon              1   downwelling_longwave_flux_in_air
# rldcs_CFmon            1   downwelling_longwave_flux_in_air_assuming_clear_sky
# rlu_CFmon              1   upwelling_longwave_flux_in_air
# rlucs_CFmon            4   upwelling_longwave_flux_in_air_assuming_clear_sky
# rsd_CFmon              1   downwelling_shortwave_flux_in_air
# rsdcs_CFmon            1   downwelling_shortwave_flux_in_air_assuming_clear_sky
# rsu_CFmon              1   upwelling_shortwave_flux_in_air
# rsucs_CFmon            1   upwelling_shortwave_flux_in_air_assuming_clear_sky
# ta_CFmon               1   air_temperature
# uqint_Emon             7   integral_of_product_of_eastward_wind_and_specific_humidity_wrt_height
# vqint_Emon             7   integral_of_product_of_northward_wind_and_specific_humidity_wrt_height
# epfz_EmonZ            28   upward_eliassen_palm_flux_in_air
# snc_LImon              5   surface_snow_area_fraction
# snd_LImon             34   surface_snow_thickness
# snw_LImon              7   surface_snow_amount
# tsn_LImon              1   temperature_in_surface_snow
# mrlsl_Lmon            34   moisture_content_of_soil_layer
# mrro_Lmon             38   runoff_flux
# mrros_Lmon             5   surface_runoff_flux
# mrso_Lmon             72   soil_moisture_content
# mrsos_Lmon             7   moisture_content_of_soil_layer
# tran_Lmon              1   transpiration_flux
# ficeberg_Omon          1   water_flux_into_sea_water_from_icebergs
# friver_Omon            7   water_flux_into_sea_water_from_rivers
# hfbasin_Omon          10   northward_ocean_heat_transport
# hfcorr_Omon           14   heat_flux_correction
# hfds_Omon             66   surface_downward_heat_flux_in_sea_water
# hfx_Omon               1   ocean_heat_x_transport
# hfy_Omon               1   ocean_heat_y_transport
# htovgyre_Omon          2   northward_ocean_heat_transport_due_to_gyre
# htovovrt_Omon          2   northward_ocean_heat_transport_due_to_overturning
# mlotst_Omon          217   ocean_mixed_layer_thickness_defined_by_sigma_t
# msftbarot_Omon         4   ocean_barotropic_mass_streamfunction
# msftmyz_Omon          11   ocean_meridional_overturning_mass_streamfunction
# msftmz_Omon            5   ocean_meridional_overturning_mass_streamfunction
# msftyz_Omon            2   ocean_y_overturning_mass_streamfunction
# so_Omon              228   sea_water_salinity
# soga_Omon             11   sea_water_salinity
# sos_Omon              22   sea_surface_salinity
# tauuo_Omon           150   surface_downward_x_stress
# tauvo_Omon             4   surface_downward_y_stress
# thetao_Omon          472   sea_water_potential_temperature
# tos_Omon             228   sea_surface_temperature
# umo_Omon               6   ocean_mass_x_transport
# uo_Omon              318   sea_water_x_velocity
# vmo_Omon              29   ocean_mass_y_transport
# vo_Omon              443   sea_water_y_velocity
# wmo_Omon               1   upward_ocean_mass_transport
# zos_Omon              97   sea_surface_height_above_geoid
# uso_PrimOmon           4   product_of_xward_sea_water_velocity_and_salinity
# uto_PrimOmon           4   product_of_xward_sea_water_velocity_and_temperature
# vso_PrimOmon           4   product_of_yward_sea_water_velocity_and_salinity
# vto_PrimOmon          15   product_of_yward_sea_water_velocity_and_temperature
# wo_PrimOmon            2   upward_sea_water_velocity
# zg_PrimmonZ            2   geopotential_height
# siconc_SImon         152   sea_ice_area_fraction
# sispeed_SImon          9   sea_ice_speed
# sithick_SImon         35   sea_ice_thickness
# sitimefrac_SImon       2   sea_ice_time_fraction
# siu_SImon             25   sea_ice_x_velocity
# siv_SImon             98   sea_ice_y_velocity
# sivol_SImon          104   sea_ice_thickness

# %% [markdown]
# Display them again in popularity order

# %%
popularity_ordered = OrderedDict(sorted(var_reqs.items(), key=lambda x: x[1], reverse=True))
for vr in popularity_ordered:
    print('{:<20} {:3}   {}'.format(vr.cmor_name + '_' + vr.table_name, var_reqs[vr], vr.standard_name))
# Out:
# pr_Amon              1261   precipitation_flux
# ts_Amon              834   surface_temperature
# psl_Amon             828   air_pressure_at_sea_level
# tas_Amon             692   air_temperature
# zg_day               544   geopotential_height
# ua_Amon              513   eastward_wind
# thetao_Omon          472   sea_water_potential_temperature
# vo_Omon              443   sea_water_y_velocity
# va_Amon              417   northward_wind
# pr_day               367   precipitation_flux
# zg_Amon              361   geopotential_height
# ta_Amon              354   air_temperature
# hus_Amon             333   specific_humidity
# evspsbl_Amon         329   water_evaporation_flux
# huss_Amon            323   specific_humidity
# ps_Amon              322   surface_air_pressure
# uo_Omon              318   sea_water_x_velocity
# clt_Amon             314   cloud_area_fraction
# hfls_Amon            236   surface_upward_latent_heat_flux
# hfss_Amon            234   surface_upward_sensible_heat_flux
# tos_Omon             228   sea_surface_temperature
# so_Omon              228   sea_water_salinity
# mlotst_Omon          217   ocean_mixed_layer_thickness_defined_by_sigma_t
# rlds_Amon            202   surface_downwelling_longwave_flux_in_air
# ua_day               194   eastward_wind
# rsds_Amon            178   surface_downwelling_shortwave_flux_in_air
# rsus_Amon            172   surface_upwelling_shortwave_flux_in_air
# va_day               161   northward_wind
# siconc_SImon         152   sea_ice_area_fraction
# tasmax_day           152   air_temperature
# tauuo_Omon           150   surface_downward_x_stress
# pr_3hr               146   precipitation_flux
# wap_Amon             144   lagrangian_tendency_of_air_pressure
# rlus_Amon            131   surface_upwelling_longwave_flux_in_air
# zg23_Primday         121   geopotential_height
# vas_6hrPlevPt        112   northward_wind
# zg7h_Prim3hrPt       111   geopotential_height
# uas_6hrPlevPt        110   eastward_wind
# zg7h_6hrPlevPt       107   geopotential_height
# sivol_SImon          104   sea_ice_thickness
# psl_6hrPlevPt        100   air_pressure_at_sea_level
# siv_SImon             98   sea_ice_y_velocity
# zos_Omon              97   sea_surface_height_above_geoid
# pr_Prim6hr            96   precipitation_flux
# rsut_Amon             88   toa_outgoing_shortwave_flux
# prw_Amon              87   atmosphere_water_vapor_content
# ta_day                85   air_temperature
# vas_day               84   northward_wind
# rlut_Amon             83   toa_outgoing_longwave_flux
# rsdt_Amon             82   toa_incoming_shortwave_flux
# uas_day               81   eastward_wind
# tas_day               74   air_temperature
# mrso_Lmon             72   soil_moisture_content
# uas_3hr               72   eastward_wind
# psl_day               72   air_pressure_at_sea_level
# vas_3hr               70   northward_wind
# prc_Amon              68   convective_precipitation_flux
# ua_6hrPlevPt          67   eastward_wind
# hfds_Omon             66   surface_downward_heat_flux_in_sea_water
# va_6hrPlevPt          65   northward_wind
# tasmin_day            64   air_temperature
# sfcWindmax_day        62   wind_speed
# hus_day               61   specific_humidity
# ua7h_6hrPlevPt        52   eastward_wind
# prc_Prim6hr           52   convective_precipitation_flux
# va7h_6hrPlevPt        48   northward_wind
# huss_3hr              48   specific_humidity
# rldscs_Amon           47   surface_downwelling_longwave_flux_in_air_assuming_clear_sky
# prw_E3hr              47   atmosphere_water_vapor_content
# ts_Primday            46   surface_temperature
# rsdscs_Amon           45   surface_downwelling_shortwave_flux_in_air_assuming_clear_sky
# rlds_3hr              45   surface_downwelling_longwave_flux_in_air
# rsutcs_Amon           43   toa_outgoing_shortwave_flux_assuming_clear_sky
# hfls_3hr              43   surface_upward_latent_heat_flux
# rlutcs_Amon           42   toa_outgoing_longwave_flux_assuming_clear_sky
# sfcWind_6hrPlevPt     38   wind_speed
# mrro_Lmon             38   runoff_flux
# rlus_3hr              38   surface_upwelling_longwave_flux_in_air
# hus7h_6hrPlevPt       37   specific_humidity
# sithick_SImon         35   sea_ice_thickness
# hur_Amon              34   relative_humidity
# snd_LImon             34   surface_snow_thickness
# mrlsl_Lmon            34   moisture_content_of_soil_layer
# hfss_3hr              34   surface_upward_sensible_heat_flux
# rsuscs_Amon           33   surface_upwelling_shortwave_flux_in_air_assuming_clear_sky
# ua7h_E3hrPt           33   eastward_wind
# rsus_3hr              33   surface_upwelling_shortwave_flux_in_air
# prsn_Amon             32   snowfall_flux
# vas_Amon              32   northward_wind
# sfcWind_day           31   wind_speed
# hfls_day              31   surface_upward_latent_heat_flux
# va7h_E3hrPt           30   northward_wind
# rldscs_3hr            30   surface_downwelling_longwave_flux_in_air_assuming_clear_sky
# uas_Prim1hr           29   eastward_wind
# uas_Amon              29   eastward_wind
# ta7h_E3hrPt           29   air_temperature
# vmo_Omon              29   ocean_mass_y_transport
# pr_E1hr               28   precipitation_flux
# epfz_EmonZ            28   upward_eliassen_palm_flux_in_air
# psl_E3hr              27   air_pressure_at_sea_level
# zg27_6hrPlevPt        27   geopotential_height
# tauu_Amon             26   surface_downward_eastward_stress
# tauv_Amon             26   surface_downward_northward_stress
# mrro_day              26   runoff_flux
# siu_SImon             25   sea_ice_x_velocity
# huss_day              25   specific_humidity
# tasmax_Amon           25   air_temperature
# vas_Prim1hr           24   northward_wind
# rlut_day              24   toa_outgoing_longwave_flux
# hus7h_E3hrPt          24   specific_humidity
# tasmin_Amon           23   air_temperature
# tos_Oday              22   sea_surface_temperature
# sos_Omon              22   sea_surface_salinity
# mrro_3hr              22   runoff_flux
# huss_6hrPlevPt        21   specific_humidity
# cl_Amon               20   cloud_area_fraction_in_atmosphere_layer
# hfss_day              19   surface_upward_sensible_heat_flux
# tas_Prim1hr           18   air_temperature
# siv_SIday             18   sea_ice_y_velocity
# ps_3hr                18   surface_air_pressure
# wap_day               18   lagrangian_tendency_of_air_pressure
# mrsos_day             18   moisture_content_of_soil_layer
# clt_day               18   cloud_area_fraction
# siu_SIday             17   sea_ice_x_velocity
# sfcWind_Prim3hr       17   wind_speed
# rsds_3hr              15   surface_downwelling_shortwave_flux_in_air
# ps_Prim6hr            15   surface_air_pressure
# vto_PrimOmon          15   product_of_yward_sea_water_velocity_and_temperature
# rlds_day              15   surface_downwelling_longwave_flux_in_air
# psl_6hrPlev           14   air_pressure_at_sea_level
# zg10_Primday          14   geopotential_height
# hfcorr_Omon           14   heat_flux_correction
# tas_3hr               13   air_temperature
# prc_3hr               11   convective_precipitation_flux
# msftmyz_Omon          11   ocean_meridional_overturning_mass_streamfunction
# soga_Omon             11   sea_water_salinity
# ps_CFday              10   surface_air_pressure
# hfbasin_Omon          10   northward_ocean_heat_transport
# sispeed_SImon          9   sea_ice_speed
# evspsbl_Primday        9   water_evaporation_flux
# ua23_Primday           9   eastward_wind
# prsn_3hr               9   snowfall_flux
# rsds_Prim1hr           8   surface_downwelling_shortwave_flux_in_air
# clwvi_CFday            8   atmosphere_cloud_condensed_water_content
# psl_E3hrPt             8   air_pressure_at_sea_level
# zg_EdayZ               8   geopotential_height
# tas_6hrPlevPt          8   air_temperature
# mrsos_3hr              8   moisture_content_of_soil_layer
# va23_Primday           8   northward_wind
# ta23_Primday           8   air_temperature
# snw_LImon              7   surface_snow_amount
# friver_Omon            7   water_flux_into_sea_water_from_rivers
# wsgmax_Prim6hr         7   wind_speed_of_gust
# mrsos_Lmon             7   moisture_content_of_soil_layer
# uqint_Emon             7   integral_of_product_of_eastward_wind_and_specific_humidity_wrt_height
# vqint_Emon             7   integral_of_product_of_northward_wind_and_specific_humidity_wrt_height
# ta_6hrPlevPt           6   air_temperature
# ta7h_6hrPlevPt         6   air_temperature
# pfull_Amon             6   air_pressure
# clivi_CFday            6   atmosphere_cloud_ice_content
# zos_PrimOday           6   sea_surface_height_above_geoid
# umo_Omon               6   ocean_mass_x_transport
# phalf_Amon             5   air_pressure
# rsut_CFday             5   toa_outgoing_shortwave_flux
# siconc_SIday           5   sea_ice_area_fraction
# mrros_Lmon             5   surface_runoff_flux
# rsdt_CFday             5   toa_incoming_shortwave_flux
# msftmz_Omon            5   ocean_meridional_overturning_mass_streamfunction
# snc_LImon              5   surface_snow_area_fraction
# va50m_Prim1hr          4   northward_wind
# ua50m_Prim1hr          4   eastward_wind
# clt_Prim1hr            4   cloud_area_fraction_in_atmosphere_layer
# clw_Amon               4   mass_fraction_of_cloud_liquid_water_in_air
# cli_Amon               4   mass_fraction_of_cloud_ice_in_air
# rlucs_CFmon            4   upwelling_longwave_flux_in_air_assuming_clear_sky
# ua_CFday               4   eastward_wind
# va_CFday               4   northward_wind
# ps_Prim6hrPt           4   surface_air_pressure
# wap7h_E3hrPt           4   lagrangian_tendency_of_air_pressure
# tauvo_Omon             4   surface_downward_y_stress
# snw_day                4   surface_snow_amount
# uto_PrimOmon           4   product_of_xward_sea_water_velocity_and_temperature
# uso_PrimOmon           4   product_of_xward_sea_water_velocity_and_salinity
# vso_PrimOmon           4   product_of_yward_sea_water_velocity_and_salinity
# msftbarot_Omon         4   ocean_barotropic_mass_streamfunction
# tauu_Eday              4   surface_downward_eastward_stress
# ua100m_Prim3hrPt       3   eastward_wind
# va100m_Prim3hrPt       3   northward_wind
# rsdscs_3hr             3   surface_downwelling_shortwave_flux_in_air_assuming_clear_sky
# hurs_Amon              3   relative_humidity
# sfcWind_Amon           3   wind_speed
# clw_CFday              3   mass_fraction_of_cloud_liquid_water_in_air
# phalf_CFday            3   air_pressure
# va4_Prim6hr            3   northward_wind
# rsdsdiff_Prim1hr       2   surface_diffuse_downwelling_shortwave_flux_in_air
# clt_Prim6hr            2   cloud_area_fraction
# clt_Prim6hrPt          2   cloud_area_fraction
# zg_PrimmonZ            2   geopotential_height
# rlutcs_CFday           2   toa_outgoing_longwave_flux_assuming_clear_sky
# rsutcs_CFday           2   toa_outgoing_shortwave_flux_assuming_clear_sky
# hus4_Prim6hr           2   specific_humidity
# ua4_Prim6hr            2   eastward_wind
# clt_3hr                2   cloud_area_fraction
# htovgyre_Omon          2   northward_ocean_heat_transport_due_to_gyre
# htovovrt_Omon          2   northward_ocean_heat_transport_due_to_overturning
# hfls_Prim6hr           2   surface_upward_latent_heat_flux
# msftyz_Omon            2   ocean_y_overturning_mass_streamfunction
# vo_PrimOday            2   sea_water_y_velocity
# ua_Eday                2   eastward_wind
# sitimefrac_SImon       2   sea_ice_time_fraction
# ua_PrimdayPt           2   eastward_wind
# rsdt_E3hr              2   toa_incoming_shortwave_flux
# wo_PrimOmon            2   upward_sea_water_velocity
# ua50m_Prim3hrPt        1   eastward_wind
# va50m_Prim3hrPt        1   northward_wind
# tso_3hr                1   sea_surface_temperature
# ts_6hrPlevPt           1   surface_temperature
# ua850_E3hrPt           1   eastward_wind
# va850_E3hrPt           1   northward_wind
# ficeberg_Omon          1   water_flux_into_sea_water_from_icebergs
# tran_Lmon              1   transpiration_flux
# hus_CFmon              1   specific_humidity
# hur_CFmon              1   relative_humidity
# ta_CFmon               1   air_temperature
# rsdcs_CFmon            1   downwelling_shortwave_flux_in_air_assuming_clear_sky
# rldcs_CFmon            1   downwelling_longwave_flux_in_air_assuming_clear_sky
# rsucs_CFmon            1   upwelling_shortwave_flux_in_air_assuming_clear_sky
# rsd_CFmon              1   downwelling_shortwave_flux_in_air
# rld_CFmon              1   downwelling_longwave_flux_in_air
# rsu_CFmon              1   upwelling_shortwave_flux_in_air
# rlu_CFmon              1   upwelling_longwave_flux_in_air
# hfx_Omon               1   ocean_heat_x_transport
# hfy_Omon               1   ocean_heat_y_transport
# uo_PrimOday            1   sea_water_x_velocity
# tsn_LImon              1   temperature_in_surface_snow
# va_Eday                1   northward_wind
# wmo_Omon               1   upward_ocean_mass_transport
# va10_Primday           1   northward_wind
# ua10_Primday           1   eastward_wind
# hus10_Primday          1   specific_humidity
# tos_3hr                1   sea_surface_temperature
# tslsi_3hr              1   surface_temperature
# ua1000_Prim6hrPt       1   eastward_wind
# psl_CF3hr              1   air_pressure_at_sea_level
# sftlf_fx               1   land_area_fraction
# sfcWindmax_Prim3hr     1   wind_speed
# sfcWindmax_Prim6hr     1   wind_speed_of_gust
# rsds_Prim6hr           1   surface_downwelling_shortwave_flux_in_air
# vortmean_6hrPlevPt     1   atmosphere_relative_vorticity

# %% [markdown]
# Look at the variables that have never been retrieved.
#
# Below is a list of the Stream 1 and 2 variables that have been uploaded by at least one model, but have never been requested for retrieval from tape to disk.

# %%
drs = DataRequest.objects.filter(datafile__isnull=False).distinct()
vrs_ids = [vrs_id[0] for vrs_id in set(list(drs.values_list('variable_request')))]
vrs = VariableRequest.objects.filter(id__in=vrs_ids)
for vr in vrs.distinct().order_by('frequency', 'table_name', 'cmor_name'):
    if vr not in var_reqs_ordered:
        print('{:<23} {}'.format(vr.cmor_name + '_' + vr.table_name, vr.standard_name))
# Out:
# prc_E1hr                convective_precipitation_flux
# ps_Prim1hr              surface_air_pressure
# rsdsdiffmax_Prim1hr     surface_diffuse_downwelling_shortwave_flux_in_air
# rsdsdiffmin_Prim1hr     surface_diffuse_downwelling_shortwave_flux_in_air
# rsdsmax_Prim1hr         surface_downwelling_shortwave_flux_in_air
# rsdsmin_Prim1hr         surface_downwelling_shortwave_flux_in_air
# sfcWindmax_Prim1hr      wind_speed
# sfcWindmin_Prim1hr      wind_speed
# wsgmax_Prim1hr          wind_speed_of_gust
# rsdsdiff_3hr            surface_diffuse_downwelling_shortwave_flux_in_air
# rsuscs_3hr              surface_upwelling_shortwave_flux_in_air_assuming_clear_sky
# clivi_E3hr              atmosphere_cloud_ice_content
# clwvi_E3hr              atmosphere_cloud_condensed_water_content
# prcsh_E3hr              hallow_convective_precipitation_flux
# prra_E3hr               rainfall_flux
# rlut_E3hr               toa_outgoing_longwave_flux
# rlutcs_E3hr             toa_outgoing_longwave_flux_assuming_clear_sky
# rsut_E3hr               toa_outgoing_shortwave_flux
# rsutcs_E3hr             toa_outgoing_shortwave_flux_assuming_clear_sky
# clisccp_E3hrPt          cloud_area_fraction_in_atmosphere_layer
# evspsbl_Prim3hr         water_evaporation_flux
# hus100_Prim3hrPt        specific_humidity
# hus1000_Prim3hrPt       specific_humidity
# ta100_Prim3hrPt         air_temperature
# ua100_Prim3hrPt         eastward_wind
# ua1000_Prim3hrPt        eastward_wind
# va100_Prim3hrPt         northward_wind
# va1000_Prim3hrPt        northward_wind
# vortmean_Prim3hrPt      atmosphere_relative_vorticity
# ps_CF3hr                surface_air_pressure
# sfcWind_CF3hr           wind_speed
# albdiffbnd_E3hrPt       band_diffuse_albedo
# albdirbnd_E3hrPt        band_direct_albedo
# ps_E3hrPt               surface_air_pressure
# hus4_6hrPlev            specific_humidity
# pr_6hrPlev              precipitation_flux
# tas_6hrPlev             air_temperature
# uas_6hrPlev             eastward_wind
# vas_6hrPlev             northward_wind
# wap4_6hrPlev            lagrangian_tendency_of_air_pressure
# zg1000_6hrPlev          geopotential_height
# hus27_6hrPlevPt         specific_humidity
# mrlsl_6hrPlevPt         moisture_content_of_soil_layer
# mrsos_6hrPlevPt         moisture_content_of_soil_layer
# snw_6hrPlevPt           surface_snow_amount
# ta27_6hrPlevPt          air_temperature
# tsl_6hrPlevPt           soil_temperature
# wbptemp7h_6hrPlevPt     wet_bulb_potential_temperature
# zg500_6hrPlevPt         geopotential_height
# hfss_Prim6hr            surface_upward_sensible_heat_flux
# mrro_Prim6hr            runoff_flux
# prsn_Prim6hr            snowfall_flux
# rlds_Prim6hr            surface_downwelling_longwave_flux_in_air
# rldscs_Prim6hr          surface_downwelling_longwave_flux_in_air_assuming_clear_sky
# rlus_Prim6hr            surface_upwelling_longwave_flux_in_air
# rsdscs_Prim6hr          surface_downwelling_shortwave_flux_in_air_assuming_clear_sky
# rsdsdiff_Prim6hr        surface_diffuse_downwelling_shortwave_flux_in_air
# rsus_Prim6hr            surface_upwelling_shortwave_flux_in_air
# rsuscs_Prim6hr          surface_upwelling_shortwave_flux_in_air_assuming_clear_sky
# hus1000_Prim6hrPt       specific_humidity
# thetapv2_Prim6hrPt      theta_on_pv2_surface
# tslsi_Prim6hrPt         surface_temperature
# tso_Prim6hrPt           sea_surface_temperature
# va1000_Prim6hrPt        northward_wind
# uo_PrimO6hr             sea_water_x_velocity
# vo_PrimO6hr             sea_water_y_velocity
# rv850_6hrPlevPt         atmosphere_relative_vorticity
# ua850_6hrPlevPt         eastward_wind
# va850_6hrPlevPt         northward_wind
# zg500_AERday            geopotential_height
# albisccp_CFday          cloud_albedo
# ccb_CFday               air_pressure_at_convective_cloud_base
# cct_CFday               air_pressure_at_convective_cloud_top
# cl_CFday                cloud_area_fraction_in_atmosphere_layer
# clcalipso_CFday         cloud_area_fraction_in_atmosphere_layer
# clhcalipso_CFday        cloud_area_fraction_in_atmosphere_layer
# cli_CFday               mass_fraction_of_cloud_ice_in_air
# clisccp_CFday           cloud_area_fraction_in_atmosphere_layer
# cllcalipso_CFday        cloud_area_fraction_in_atmosphere_layer
# clmcalipso_CFday        cloud_area_fraction_in_atmosphere_layer
# cltcalipso_CFday        cloud_area_fraction
# cltisccp_CFday          cloud_area_fraction
# hur_CFday               relative_humidity
# hus_CFday               specific_humidity
# mc_CFday                atmosphere_net_upward_convective_mass_flux
# pctisccp_CFday          air_pressure_at_cloud_top
# pfull_CFday             air_pressure
# rldscs_CFday            surface_downwelling_longwave_flux_in_air_assuming_clear_sky
# rsdscs_CFday            surface_downwelling_shortwave_flux_in_air_assuming_clear_sky
# rsuscs_CFday            surface_upwelling_shortwave_flux_in_air_assuming_clear_sky
# ta_CFday                air_temperature
# ta700_CFday             air_temperature
# wap_CFday               lagrangian_tendency_of_air_pressure
# wap500_CFday            lagrangian_tendency_of_air_pressure
# zg_CFday                geopotential_height
# hur_day                 relative_humidity
# hurs_day                relative_humidity
# hursmax_day             relative_humidity
# hursmin_day             relative_humidity
# mrso_day                soil_moisture_content
# omldamax_day            ocean_mixed_layer_thickness_defined_by_mixing_scheme
# prc_day                 convective_precipitation_flux
# prsn_day                snowfall_flux
# rlus_day                surface_upwelling_longwave_flux_in_air
# rsds_day                surface_downwelling_shortwave_flux_in_air
# rsus_day                surface_upwelling_shortwave_flux_in_air
# snc_day                 surface_snow_area_fraction
# tslsi_day               surface_temperature
# hus_Eday                specific_humidity
# lwsnl_Eday              liquid_water_content_of_snow_layer
# mlotst_Eday             ocean_mixed_layer_thickness_defined_by_sigma_t
# mrros_Eday              surface_runoff_flux
# mrsol_Eday              moisture_content_of_soil_layer
# rivo_Eday               water_flux_to_downstream
# rzwc_Eday               water_content_of_root_zone
# sic_Eday                sea_ice_area_fraction
# snd_Eday                surface_snow_thickness
# snm_Eday                surface_snow_melt_flux
# snw_Eday                surface_snow_amount
# t20d_Eday               depth_of_isosurface_of_sea_water_potential_temperature
# ta_Eday                 air_temperature
# ta850_Eday              air_temperature
# tauv_Eday               surface_downward_northward_stress
# tdps_Eday               dew_point_temperature
# ts_Eday                 surface_temperature
# epfz_EdayZ              upward_eliassen_palm_flux_in_air
# utendnogw_EdayZ         tendency_of_eastward_wind_due_to_nonorographic_gravity_wave_drag
# utendogw_EdayZ          tendency_of_eastward_wind_due_to_orographic_gravity_wave_drag
# vtem_EdayZ              northward_transformed_eulerian_mean_air_velocity
# wtem_EdayZ              unset
# omldamax_Oday           ocean_mixed_layer_thickness_defined_by_mixing_scheme
# sos_Oday                sea_surface_salinity
# tossq_Oday              square_of_sea_surface_temperature
# hus23_Primday           specific_humidity
# mrlsl_Primday           moisture_content_of_soil_layer
# mrso_Primday            soil_moisture_content
# prmax_Primday           precipitation_flux
# prmin_Primday           precipitation_flux
# ta10_Primday            air_temperature
# uneutrals_Primday       eastward_neurtral_wind
# vneutrals_Primday       northward_neutral_wind
# wap10_Primday           lagrangian_tendency_of_air_pressure
# wap23_Primday           lagrangian_tendency_of_air_pressure
# va_PrimdayPt            northward_wind
# mlotst_PrimOday         ocean_mixed_layer_thickness_defined_by_sigma_t
# so_PrimOday             sea_water_salinity
# tauuo_PrimOday          surface_downward_x_stress
# tauvo_PrimOday          surface_downward_y_stress
# thetao_PrimOday         sea_water_potential_temperature
# sidivvel_PrimSIday      divergence_of_sea_ice_velocity
# siforceintstrx_PrimSIday internal_stress_in_sea_ice_x
# siforceintstry_PrimSIday internal_stress_in_sea_ice_y
# simassacrossline_PrimSIday sea_ice_transport_across_line
# sistrxdtop_PrimSIday    surface_downward_x_stress
# sistrxubot_PrimSIday    sea_ice_base_upward_x_stress
# sistrydtop_PrimSIday    surface_downward_y_stress
# sistryubot_PrimSIday    sea_ice_base_upward_y_stress
# sitimefrac_PrimSIday    sea_ice_time_fraction
# siu_PrimSIday           sea_ice_x_velocity
# siv_PrimSIday           sea_ice_y_velocity
# siconca_SIday           sea_ice_area_fraction
# sisnthick_SIday         surface_snow_thickness
# sispeed_SIday           sea_ice_speed
# sitemptop_SIday         sea_ice_surface_temperature
# sithick_SIday           sea_ice_thickness
# sitimefrac_SIday        sea_ice_time_fraction
# sftgrf_Efx              grounded_ice_sheet_area_fraction
# areacella_fx            cell_area
# areacellr_fx            cell_area
# mrsofc_fx               soil_moisture_content_at_field_capacity
# orog_fx                 surface_altitude
# rootd_fx                root_depth
# sftgif_fx               land_ice_area_fraction
# zfull_fx                height_above_reference_ellipsoid
# areacello_Ofx           cell_area
# basin_Ofx               region
# deptho_Ofx              sea_floor_depth_below_geoid
# hfgeou_Ofx              upward_geothermal_heat_flux_at_sea_floor
# masscello_Ofx           sea_water_mass_per_unit_area
# thkcello_Ofx            cell_thickness
# volcello_Ofx            ocean_volume
# abs550aer_AERmon        atmosphere_absorption_optical_thickness_due_to_ambient_aerosol
# cltc_AERmon             convective_cloud_area_fraction
# cod_AERmon              atmosphere_optical_thickness_due_to_cloud
# lwp_AERmon              atmosphere_mass_content_of_cloud_liquid_water
# od550aer_AERmon         atmosphere_optical_thickness_due_to_ambient_aerosol_particles
# od550bc_AERmon          atmosphere_optical_thickness_due_to_black_carbon_ambient_aerosol
# od550dust_AERmon        atmosphere_optical_thickness_due_to_dust_ambient_aerosol
# od550oa_AERmon          atmosphere_optical_thickness_due_to_particulate_organic_matter_ambient_aerosol
# od550so4_AERmon         atmosphere_optical_thickness_due_to_sulfate_ambient_aerosol
# od550ss_AERmon          atmosphere_optical_thickness_due_to_seasalt_ambient_aerosol
# ps_AERmon               surface_air_pressure
# ptp_AERmon              tropopause_air_pressure
# reffclwtop_AERmon       effective_radius_of_cloud_liquid_water_particle_at_liquid_water_cloud_top
# rlutaf_AERmon           toa_outgoing_longwave_flux
# rlutcsaf_AERmon         toa_outgoing_longwave_flux_assuming_clear_sky
# rsutaf_AERmon           toa_outgoing_shortwave_flux
# rsutcsaf_AERmon         toa_outgoing_shortwave_flux_assuming_clear_sky
# tatp_AERmon             tropopause_air_temperature
# toz_AERmon              equivalent_thickness_at_stp_of_atmosphere_ozone_content
# ttop_AERmon             air_temperature_at_cloud_top
# ua_AERmon               eastward_wind
# va_AERmon               northward_wind
# ztp_AERmon              tropopause_altitude
# ccb_Amon                air_pressure_at_convective_cloud_base
# cct_Amon                air_pressure_at_convective_cloud_top
# ch4global_Amon          mole_fraction_of_methane_in_air
# ci_Amon                 convection_time_fraction
# clivi_Amon              atmosphere_cloud_ice_content
# clwvi_Amon              atmosphere_cloud_condensed_water_content
# co2mass_Amon            atmosphere_mass_of_carbon_dioxide
# mc_Amon                 atmosphere_net_upward_convective_mass_flux
# n2oglobal_Amon          mole_fraction_of_nitrous_oxide_in_air
# rtmt_Amon               net_downward_radiative_flux_at_top_of_atmosphere_model
# sbl_Amon                surface_snow_and_ice_sublimation_flux
# sci_Amon                shallow_convection_time_fraction
# albisccp_CFmon          cloud_albedo
# clc_CFmon               convective_cloud_area_fraction_in_atmosphere_layer
# clcalipso_CFmon         cloud_area_fraction_in_atmosphere_layer
# clhcalipso_CFmon        cloud_area_fraction_in_atmosphere_layer
# clic_CFmon              mass_fraction_of_convective_cloud_ice_in_air
# clis_CFmon              mass_fraction_of_stratiform_cloud_ice_in_air
# clisccp_CFmon           cloud_area_fraction_in_atmosphere_layer
# cllcalipso_CFmon        cloud_area_fraction_in_atmosphere_layer
# clmcalipso_CFmon        cloud_area_fraction_in_atmosphere_layer
# cls_CFmon               stratiform_cloud_area_fraction_in_atmosphere_layer
# cltcalipso_CFmon        cloud_area_fraction
# cltisccp_CFmon          cloud_area_fraction
# clwc_CFmon              mass_fraction_of_convective_cloud_liquid_water_in_air
# clws_CFmon              mass_fraction_of_stratiform_cloud_liquid_water_in_air
# mcd_CFmon               atmosphere_downdraft_convective_mass_flux
# mcu_CFmon               atmosphere_updraft_convective_mass_flux
# pctisccp_CFmon          air_pressure_at_cloud_top
# rld4co2_CFmon           downwelling_longwave_flux_in_air
# rldcs4co2_CFmon         downwelling_longwave_flux_in_air_assuming_clear_sky
# rlu4co2_CFmon           upwelling_longwave_flux_in_air
# rlucs4co2_CFmon         upwelling_longwave_flux_in_air_assuming_clear_sky
# rlut4co2_CFmon          toa_outgoing_longwave_flux
# rlutcs4co2_CFmon        toa_outgoing_longwave_flux_assuming_clear_sky
# rsd4co2_CFmon           downwelling_shortwave_flux_in_air
# rsdcs4co2_CFmon         downwelling_shortwave_flux_in_air_assuming_clear_sky
# rsu4co2_CFmon           upwelling_shortwave_flux_in_air
# rsucs4co2_CFmon         upwelling_shortwave_flux_in_air_assuming_clear_sky
# rsut4co2_CFmon          toa_outgoing_shortwave_flux
# rsutcs4co2_CFmon        toa_outgoing_shortwave_flux_assuming_clear_sky
# tnhus_CFmon             tendency_of_specific_humidity
# tnhusa_CFmon            tendency_of_specific_humidity_due_to_advection
# tnhusc_CFmon            tendency_of_specific_humidity_due_to_convection
# tnhusmp_CFmon           tendency_of_specific_humidity_due_to_model_physics
# tnhusscpbl_CFmon        tendency_of_specific_humidity_due_to_stratiform_cloud_and_precipitation_and_boundary_layer_mixing
# tnt_CFmon               tendency_of_air_temperature
# tnta_CFmon              tendency_of_air_temperature_due_to_advection
# tntc_CFmon              tendency_of_air_temperature_due_to_convection
# tntmp_CFmon             tendency_of_air_temperature_due_to_model_physics
# tntr_CFmon              tendency_of_air_temperature_due_to_radiative_heating
# tntscpbl_CFmon          tendency_of_air_temperature_due_to_stratiform_cloud_and_precipitation_and_boundary_layer_mixing
# cldicemxrat27_Emon      cloud_ice_mixing_ratio
# cldwatmxrat27_Emon      cloud_liquid_water_mixing_ratio
# clwvic_Emon             atmosphere_convective_cloud_condensed_water_content
# cropFracC3_Emon         area_fraction
# cropFracC4_Emon         area_fraction
# evspsblpot_Emon         water_potential_evaporation_flux
# grassFracC3_Emon        area_fraction
# grassFracC4_Emon        area_fraction
# hcont300_Emon           heat_content_of_ocean_layer
# hus_Emon                specific_humidity
# hus27_Emon              specific_humidity
# intuadse_Emon           vertical_integral_eastward_wind_by_dry_static_energy
# intuaw_Emon             vertical_integral_eastward_wind_by_total_water
# intvadse_Emon           vertical_integral_northward_wind_by_dry_static_energy
# intvaw_Emon             vertical_integral_northward_wind_by_total_water
# mrsol_Emon              moisture_content_of_soil_layer
# mrtws_Emon              total_water_storage
# nep_Emon                surface_net_downward_mass_flux_of_carbon_dioxide_expressed_as_carbon_due_to_all_land_processes_excluding_anthropogenic_land_use_change
# nwdFracLut_Emon         missing
# orog_Emon               surface_altitude
# parasolRefl_Emon        toa_bidirectional_reflectance
# rls_Emon                surface_net_downward_longwave_flux
# rss_Emon                surface_net_downward_shortwave_flux
# sfcWindmax_Emon         wind_speed
# t2_Emon                 square_of_air_temperature
# t20d_Emon               depth_of_isosurface_of_sea_water_potential_temperature
# ta27_Emon               air_temperature
# thetaot_Emon            sea_water_potential_temperature
# thetaot2000_Emon        sea_water_potential_temperature
# thetaot300_Emon         sea_water_potential_temperature
# thetaot700_Emon         sea_water_potential_temperature
# tntmp27_Emon            tendency_of_air_temperature_due_to_model_physics
# tntrl27_Emon            tendency_of_air_temperature_due_to_longwave_heating
# tntrs27_Emon            tendency_of_air_temperature_due_to_shortwave_heating
# twap_Emon               product_of_omega_and_air_temperature
# u2_Emon                 square_of_eastward_wind
# ua27_Emon               eastward_wind
# ut_Emon                 product_of_eastward_wind_and_air_temperature
# uv_Emon                 product_of_eastward_wind_and_northward_wind
# uwap_Emon               product_of_eastward_wind_and_omega
# v2_Emon                 square_of_northward_wind
# va27_Emon               northward_wind
# vegFrac_Emon            area_fraction
# vt_Emon                 product_of_northward_wind_and_air_temperature
# vwap_Emon               product_of_northward_wind_and_omega
# wap_Emon                lagrangian_tendency_of_air_pressure
# wap2_Emon               square_of_lagrangian_tendency_of_air_pressure
# wtd_Emon                depth_of_soil_moisture_saturation
# zg27_Emon               geopotential_height
# utendnogw_EmonZ         tendency_of_eastward_wind_due_to_nonorographic_gravity_wave_drag
# vtem_EmonZ              northward_transformed_eulerian_mean_air_velocity
# vtendnogw_EmonZ         tendency_of_northward_wind_due_to_nonorographic_gravity_wave_drag
# wtem_EmonZ              unset
# agesno_LImon            age_of_surface_snow
# hfdsn_LImon             surface_downward_heat_flux_in_snow
# lwsnl_LImon             liquid_water_content_of_snow_layer
# sbl_LImon               surface_snow_and_ice_sublimation_flux
# sftgif_LImon            land_ice_area_fraction
# sftgrf_LImon            grounded_ice_sheet_area_fraction
# snm_LImon               surface_snow_melt_flux
# baresoilFrac_Lmon       area_fraction
# c3PftFrac_Lmon          area_fraction
# c4PftFrac_Lmon          area_fraction
# cropFrac_Lmon           area_fraction
# evspsblsoi_Lmon         water_evaporation_flux_from_soil
# evspsblveg_Lmon         water_evaporation_flux_from_canopy
# gpp_Lmon                gross_primary_productivity_of_biomass_expressed_as_carbon
# grassFrac_Lmon          area_fraction
# lai_Lmon                leaf_area_index
# landCoverFrac_Lmon      area_fraction
# mrfso_Lmon              soil_frozen_water_content
# npp_Lmon                net_primary_productivity_of_biomass_expressed_as_carbon
# prveg_Lmon              precipitation_flux_onto_canopy
# ra_Lmon                 plant_respiration_carbon_flux
# residualFrac_Lmon       area_fraction
# rh_Lmon                 heterotrophic_respiration_carbon_flux
# treeFrac_Lmon           area_fraction
# tsl_Lmon                soil_temperature
# agessc_Omon             sea_water_age_since_surface_contact
# bigthetao_Omon          sea_water_conservative_temperature
# bigthetaoga_Omon        sea_water_conservative_temperature
# evs_Omon                water_evaporation_flux
# ficeberg2d_Omon         water_flux_into_sea_water_from_icebergs
# fsitherm_Omon           water_flux_into_sea_water_due_to_sea_ice_thermodynamics
# hfbasinpadv_Omon        northward_ocean_heat_transport_due_to_parameterized_eddy_advection
# hfbasinpmadv_Omon       northward_ocean_heat_transport_due_to_parameterized_mesoscale_advection
# hfbasinpmdiff_Omon      northward_ocean_heat_transport_due_to_parameterized_mesoscale_diffusion
# hfevapds_Omon           temperature_flux_due_to_evaporation_expressed_as_heat_flux_out_of_sea_water
# hfgeou_Omon             upward_geothermal_heat_flux_at_sea_floor
# hfrainds_Omon           temperature_flux_due_to_rainfall_expressed_as_heat_flux_into_sea_water
# hfrunoffds2d_Omon       temperature_flux_due_to_runoff_expressed_as_heat_flux_into_sea_water
# masscello_Omon          sea_water_mass_per_unit_area
# masso_Omon              sea_water_mass
# mfo_Omon                sea_water_transport_across_line
# mlotstmax_Omon          ocean_mixed_layer_thickness_defined_by_sigma_t
# mlotstmin_Omon          ocean_mixed_layer_thickness_defined_by_sigma_t
# mlotstsq_Omon           square_of_ocean_mixed_layer_thickness_defined_by_sigma_t
# msftmzmpa_Omon          ocean_meridional_overturning_mass_streamfunction_due_to_parameterized_mesoscale_advection
# obvfsq_Omon             square_of_brunt_vaisala_frequency_in_sea_water
# pbo_Omon                sea_water_pressure_at_sea_floor
# prlq_Omon               rainfall_flux
# prsn_Omon               snowfall_flux
# rsdo_Omon               downwelling_shortwave_flux_in_sea_water
# rsntds_Omon             net_downward_shortwave_flux_at_sea_water_surface
# sfdsi_Omon              downward_sea_ice_basal_salt_flux
# sltovgyre_Omon          northward_ocean_salt_transport_due_to_gyre
# sltovovrt_Omon          northward_ocean_salt_transport_due_to_overturning
# sob_Omon                sea_water_salinity_at_sea_floor
# sosga_Omon              sea_surface_salinity
# thetaoga_Omon           sea_water_potential_temperature
# thkcello_Omon           cell_thickness
# tob_Omon                sea_water_potential_temperature_at_sea_floor
# tosga_Omon              sea_surface_temperature
# tossq_Omon              square_of_sea_surface_temperature
# volo_Omon               sea_water_volume
# wfcorr_Omon             water_flux_correction
# wfo_Omon                water_flux_into_sea_water
# wo_Omon                 upward_sea_water_velocity
# zfullo_Omon             depth_below_geoid
# zossq_Omon              square_of_sea_surface_height_above_geoid
# zostoga_Omon            global_average_thermosteric_sea_level_change
# cdnc_Primmon            number_concentration_of_cloud_liquid_water_particles_in_air
# clwvic_Primmon          atmosphere_convective_cloud_condensed_water_content
# cod_Primmon             atmosphere_optical_thickness_due_to_cloud
# lwp_Primmon             atmosphere_cloud_liquid_water_content
# ua_PrimmonZ             eastward_wind
# va_PrimmonZ             northward_wind
# vstarbar_PrimmonZ       northward_transformed_eulerian_mean_air_velocity
# wstarbar_PrimmonZ
# xnonoroggwdparam_PrimmonZ
# opottemptend_PrimOmon   tendency_of_sea_water_potential_temperature_expressed_as_heat_content
# somint_PrimOmon         integral_wrt_depth_of_product_of_sea_water_density_and_prognostic_salinity
# tomint_PrimOmon         integral_wrt_depth_of_product_of_sea_water_density_and_prognostic_temperature
# u2o_PrimOmon            square_of_sea_water_x_velocity
# v2o_PrimOmon            square_of_sea_water_y_velocity
# w2o_PrimOmon            square_of_sea_water_upward_velocity
# wso_PrimOmon            product_of_upward_sea_water_velocity_and_salinity
# wto_PrimOmon            product_of_upward_sea_water_velocity_and_salinity
# siage_SImon             age_of_sea_ice
# sialb_SImon             sea_ice_albedo
# siareaacrossline_SImon  sea_ice_area_transport_across_line
# siarean_SImon           sea_ice_area
# siareas_SImon           sea_ice_area
# sicompstren_SImon       compressive_strength_of_sea_ice
# siconca_SImon           sea_ice_area_fraction
# sidconcdyn_SImon        tendency_of_sea_ice_area_fraction_due_to_dynamics
# sidconcth_SImon         tendency_of_sea_ice_area_fraction_due_to_thermodynamics
# sidivvel_SImon          divergence_of_sea_ice_velocity
# sidmassdyn_SImon        tendency_of_sea_ice_amount_due_to_dynamics
# sidmassevapsubl_SImon   water_evaporation_flux
# sidmassgrowthbot_SImon  tendency_of_sea_ice_amount_due_to_congelation_ice_accumulation
# sidmassgrowthwat_SImon  tendency_of_sea_ice_amount_due_to_freezing_in_open_water
# sidmasslat_SImon        tendency_of_sea_ice_amount_due_to_lateral_melting
# sidmassmeltbot_SImon    tendency_of_sea_ice_amount_due_to_basal_melting
# sidmassmelttop_SImon    tendency_of_sea_ice_amount_due_to_surface_melting
# sidmasssi_SImon         tendency_of_sea_ice_amount_due_to_snow_conversion
# sidmassth_SImon         tendency_of_sea_ice_amount_due_to_thermodynamics
# sidmasstranx_SImon      sea_ice_x_transport
# sidmasstrany_SImon      sea_ice_y_transport
# siextentn_SImon         sea_ice_extent
# siextents_SImon         sea_ice_extent
# sifb_SImon              sea_ice_freeboard
# siflcondbot_SImon       conductive_heat_flux_at_sea_ice_bottom
# siflcondtop_SImon       conductive_heat_flux_at_sea_ice_surface
# siflfwbot_SImon         freshwater_flux_from_ice
# siflfwdrain_SImon       freshwater_flux_from_ice_surface
# sifllatstop_SImon       surface_upward_latent_heat_flux
# sifllwdtop_SImon        surface_downwelling_longwave_flux_in_air
# sifllwutop_SImon        surface_upwelling_longwave_flux_in_air
# siflsaltbot_SImon       salt_flux_from_ice
# siflsenstop_SImon       surface_upward_sensible_heat_flux
# siflsensupbot_SImon     ice_ocean_heat_flux
# siflswdbot_SImon        bottom_downwelling_shortwave_flux_into_ocean
# siflswdtop_SImon        surface_downwelling_shortwave_flux_in_air
# siflswutop_SImon        surface_upwelling_shortwave_flux_in_air
# sihc_SImon              integral_of_sea_ice_temperature_wrt_depth_expressed_as_heat_content
# simass_SImon            sea_ice_amount
# simassacrossline_SImon  sea_ice_transport_across_line
# sipr_SImon              rainfall_flux
# sisali_SImon            sea_ice_salinity
# sisaltmass_SImon        sea_ice_salt_mass
# sishevel_SImon          maximum_shear_of_sea_ice_velocity
# sisnconc_SImon          surface_snow_area_fraction
# sisnhc_SImon            thermal_energy_content_of_surface_snow
# sisnmass_SImon          liquid_water_content_of_surface_snow
# sisnthick_SImon         surface_snow_thickness
# sistrxdtop_SImon        surface_downward_x_stress
# sistrxubot_SImon        sea_ice_base_upward_x_stress
# sistrydtop_SImon        surface_downward_y_stress
# sistryubot_SImon        downward_y_stress_at_sea_ice_base
# sitempbot_SImon         sea_ice_bottom_temperature
# sitempsnic_SImon        sea_ice_surface_temperature
# sitemptop_SImon         sea_ice_surface_temperature
# sivoln_SImon            sea_ice_volume
# sivols_SImon            sea_ice_volume
# sndmassdyn_SImon        tendency_of_snow_mass_due_to_sea_ice_dynamics
# sndmassmelt_SImon       surface_snow_melt_flux
# sndmasssi_SImon         tendency_of_surface_snow_amount_due_to_conversion_of_snow_to_sea_ice
# sndmasssnf_SImon        snowfall_flux
# sndmasssubl_SImon       surface_snow_sublimation_flux
# snmassacrossline_SImon  snow_mass_transport_across_line
